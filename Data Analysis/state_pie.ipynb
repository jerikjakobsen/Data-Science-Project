# %%
import pandas as pd
import os

filteredDF = pd.read_csv(os.path.join('..', 'CSVFiles', 'FilteredListing+SaleData.csv'), index_col=0)

filteredDF.groupby(["State"]).size().plot(kind='pie', y= len(filteredDF), autopct='%1.0f%%' )


print(filteredDF.groupby(["State"]).describe())
print(filteredDF.groupby(["State"]).size())
# Out:
#       sale_price                                                            \
#            count          mean           std       min       25%       50%
# State
# az           2.0  4.075000e+05  1.661701e+05  290000.0  348750.0  407500.0
# ca         233.0  1.250338e+06  1.506971e+06       0.0  540005.0  800008.0
# co         142.0  4.970956e+05  3.824779e+05       0.0  330000.0  428750.0
# dc          71.0  1.030759e+06  7.753287e+05       0.0  575000.0  815000.0
# fl         625.0  4.369165e+05  6.938116e+05       0.0  175000.0  270300.0
# ga         131.0  3.851425e+05  4.066511e+05       0.0  108625.0  268500.0
# in          52.0  1.798279e+05  1.251281e+05   31800.0   95225.0  158750.0
# md         116.0  2.193300e+05  1.388431e+05       0.0  144850.0  196000.0
#
#                              Sqr Ft               ... Days On Trulia         \
#              75%         max  count         mean  ...            75%    max
# State                                             ...
# az      466250.0    525000.0    2.0  2541.000000  ...          61.50   73.0
# ca     1401014.0  13504135.0  233.0  2444.733906  ...          97.00  180.0
# co      554250.0   2532167.0  142.0  2689.823944  ...          71.50  180.0
# dc     1218500.0   3700000.0   71.0  2753.873239  ...          86.50  180.0
# fl      429000.0  11500000.0  625.0  2228.772800  ...         111.00  180.0
# ga      493950.0   2000000.0  131.0  2149.290076  ...         109.00  180.0
# in      224912.5    694999.0   52.0  2032.653846  ...          46.50  180.0
# md      279250.0    910000.0  116.0  1806.051724  ...          98.25  180.0
#
#       Zipcode                                                                  \
#         count          mean         std      min       25%      50%       75%
# State
# az        2.0  85739.000000    0.000000  85739.0  85739.00  85739.0  85739.00
# ca      233.0  90568.862661  952.935649  90002.0  90032.00  90047.0  90805.00
# co      142.0  80127.450704  106.067794  80010.0  80015.00  80205.0  80229.75
# dc       71.0  20011.239437    6.749529  20001.0  20007.00  20011.0  20018.00
# fl      625.0  32810.080000  542.220054  32202.0  32225.00  32821.0  33156.00
# ga      131.0  30319.893130   11.493980  30305.0  30311.00  30315.0  30327.00
# in       52.0  46819.192308   14.475183  46802.0  46807.00  46815.0  46825.00
# md      116.0  21221.810345   15.818489  21201.0  21211.75  21218.0  21230.00
#
#
#            max
# State
# az     85739.0
# ca     92509.0
# co     80260.0
# dc     20037.0
# fl     33647.0
# ga     30354.0
# in     46845.0
# md     21286.0
#
# [8 rows x 80 columns]
# State
# az      2
# ca    233
# co    142
# dc     71
# fl    625
# ga    131
# in     52
# md    116
# dtype: int64
